# %% [markdown]
# # Corpus preprocessing
#
# * Input: Google Drive metadata and TXT

# %%
import sys
sys.path.append('..')
from ballitoreproject import *

# %% [markdown]
# ## Metadata

# %%
# get_metadata??
get_metadata()
# Out:
# 100%|██████████| 2983/2983 [00:04<00:00, 668.74it/s]
#                                     sender           recipient        date  \
# id
# mss4-b3-f1-001               Richard Grubb  Richard Shackleton   3/19/1789
# mss4-b3-f2-001                Samuel Grubb  Richard Shackleton   3/14/1792
# mss4-b3-f3-001                 Sarah Grubb  Richard Shackleton  12/24/1789
# mss4-b3-f4-001            Sarah Tuke Grubb  Richard Shackleton   6/12/1781
# mss4-b3-f4-002            Sarah Tuke Grubb  Richard Shackleton   8/13/1781
# ...                                    ...                 ...         ...
# mss4-b2-f24-047  Margaret Shackleton Grubb  Richard Shackleton   1/18/1792
# mss4-b2-f24-048  Margaret Shackleton Grubb  Richard Shackleton   2/20/1792
# mss4-b2-f24-049  Margaret Shackleton Grubb  Richard Shackleton   4/24/1792
# mss4-b2-f24-050  Margaret Shackleton Grubb  Richard Shackleton   6/16/1792
# mss4-b2-f24-051  Margaret Shackleton Grubb  Richard Shackleton   8/19/1792
#
# ...

# %% [markdown]
# ## Adding text data

# %%
get_data(force=True)
# get_data??
# Out:
# ...
# 100%|██████████| 4560/4560 [00:00<00:00, 5320.88it/s]
#                                        sender           recipient       date  \
# id
# mss4-b1-f7-001-176               William Penn         Unknown 1.1  2/10/1690
# mss4-b1-f3-005           Abraham Shackleton I  Richard Shackleton       1744
# mss4-b1-f7-001-3                  Sophia Hume           Anne Hyam   6/1/1748
# mss4-b1-f3-005-006       Abraham Shackleton I  Richard Shackleton       1748
# mss4-b1-f7-001-15                 Sophia Hume               J. P.  5/19/1750
# ...                                       ...                 ...        ...
# consensus_text_90345943
# consensus_text_90345944
# consensus_text_90345945
# consensus_text_90345946
# consensus_text_90345947
#
#                         location from location to       notes  box   datetime  \
# id
# mss4-b1-f7-001-176             London              copy; p. 2    1 1690-02-10
# mss4-b1-f3-005                             Dublin     extract    1 1744-07-13
# ...
